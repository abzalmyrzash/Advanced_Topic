# %%
import os
import json
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import TruncatedSVD
import re
import matplotlib.pyplot as plt
import seaborn as sns
PATH = "./sample_data/"
# %matplotlib inline

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\abzal\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\abzal\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
df = pd.read_json("./sample_data/spacearxiv.json")

# %%
def preprocess_text(text, flag):
    text = text.lower()
    text = text.replace("abstract:","")
    text = re.sub("[^A-Za-z]+"," ",text)
    if flag:
        tokens = nltk.word_tokenize(text)
        tokens = [token for token in tokens if not token in stopwords.words("english")]
        text = " ".join(tokens)
    return text

# %%
df['cleaned_abstract'] = df['abstract'].apply(lambda x: preprocess_text(x,True))

# %%
df.head()
# Out:
#                                 url  ...                                   cleaned_abstract
# 0  https://arxiv.org/abs/2202.03622  ...  design novel devices specific technical intere...
# 1  https://arxiv.org/abs/2202.02773  ...  litebird lite light satellite study b mode pol...
# 2  https://arxiv.org/abs/2202.02429  ...  inverse problems exist wide variety physical d...
# 3  https://arxiv.org/abs/2202.01203  ...  precipitate matrix interactions govern mechani...
# 4  https://arxiv.org/abs/2202.00791  ...  planetary rover systems need perform terrain s...
#
# [5 rows x 8 columns]

# %%
vecr = TfidfVectorizer(min_df=5, max_df=0.95)
X = vecr.fit_transform(df["cleaned_abstract"])

# %%
kmeans = KMeans(n_clusters=3,random_state=111)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=111)

# %%
clusters = kmeans.labels_

# %%
len(list(clusters))
# Out:
# 4317

# %%
svd = TruncatedSVD(n_components=2, random_state=111)
svd_vec = svd.fit_transform(X)

# %%
svd_vec.shape
# Out:
# (4317, 2)

# %%
df['cluster'] = clusters

# %%
df['y'] = svd_vec[:,0]
df['x'] = svd_vec[:,1]

# %%
def interpret(n):
  res = dict()
  centroids = pd.DataFrame(X.todense()).groupby(clusters).mean()
  terms = vecr.get_feature_names_out()
  for i,r in centroids.iterrows():
    res[i] = ",".join([terms[t] for t in np.argsort(r)[-n:]])
  return res

# %%
cluster_map = interpret(3)
df['cluster'] = df['cluster'].map(cluster_map)

# %%
df[["title","categories","cluster"]].head()
# Out:
#                                                title  \
# 0  Title:The synergistic modulation of electronic...
# 1  Title:Probing Cosmic Inflation with the LiteBI...
# 2      Title:Verifying Inverse Model Neural Networks
# 3  Title:High pressure induced precipitation in A...
# 4   Title:Mars Terrain Segmentation with Less Labels
#
#                                           categories                  cluster
# 0            [Materials Science (cond-mat.mtrl-sci)]    system,design,control
# 1  [Instrumentation and Methods for Astrophysics ...  mission,data,spacecraft
# 2  [Machine Learning (cs.LG),  Logic in Computer ...    system,design,control
# 3  [Materials Science (cond-mat.mtrl-sci),  Other...  mission,data,spacecraft
# 4  [Computer Vision and Pattern Recognition (cs.C...    system,design,control

# %%
plt.figure(figsize=(12,12))
plt.title("The first vizualization at the course")
sns.scatterplot(data=df,y='y',x='x', hue='cluster',palette='viridis')

# %%
df['date_publ'].unique().shape
# Out:
# (3417,)

# %%
### Home Work
### Vizualize the clusters grouped by date_publ with the help of TimeLine d3js components

# %%
### Propose your idea to show technologies from spacearxiv.json with the help of Moqups and pipeline
