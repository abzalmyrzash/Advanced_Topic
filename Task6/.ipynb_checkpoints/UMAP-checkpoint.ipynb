# %%
# !pip install --user umap-learn

# %%
from sklearn import datasets
import json
from umap import UMAP
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris = datasets.load_iris()
x, y = iris["data"], iris["target"]

embedding = UMAP().fit_transform(x)

# %%
data = pd.DataFrame(embedding, columns=["Comp1","Comp2"])
data["Label"] = y

# %%
# TODO add the Target Information into  your json file
with open('UMAP.json', 'w') as f:
    embeddingList = np.array(embedding).tolist();
    yList = y.tolist()
    jsonarray = []
    for i in range(len(y)):
        jsonarray.append({"x": embeddingList[i][0], "y": embeddingList[i][1], "label": yList[i]})
#     print(jsonarray)
    json.dump(jsonarray, f, indent=2)

# %%
sns.set_context("notebook", font_scale=1.1)
sns.set_style("ticks")

sns.lmplot(x='Comp1',
           y='Comp2',
           data=data,
           fit_reg=False,
           legend=True,
           size=9,
           hue='Label',
           scatter_kws={"s":200, "alpha":0.3}
          )

plt.title("UMAP", weight='bold').set_fontsize('14')
plt.xlabel('Comp 1')
plt.ylabel('Comp 2')
# Out:
# C:\Users\abzal\anaconda3\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Text(30.390736666666676, 0.5, 'Comp 2')
